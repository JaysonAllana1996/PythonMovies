# %%
# First let's import packages that we will need for the project
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Import dataset into a dataframe
df=pd.read_csv(r'C:\Users\Jayson Naquila\Desktop\Dataset files\movies 1986-2016\movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Finding out null values per column
for col in df.columns:
    print(df[col].notnull().value_counts(), "\n")
# Out:
# name
# True    7668
# Name: count, dtype: int64
#
# rating
# True     7591
# False      77
# Name: count, dtype: int64
#
# genre
# True    7668
# Name: count, dtype: int64
#
# year
# True    7668
# Name: count, dtype: int64
#
# released
# True     7666
# False       2
# Name: count, dtype: int64
#
# score
# True     7665
# False       3
# Name: count, dtype: int64
#
# votes
# True     7665
# False       3
# Name: count, dtype: int64
#
# director
# True    7668
# Name: count, dtype: int64
#
# writer
# True     7665
# False       3
# Name: count, dtype: int64
#
# star
# True     7667
# False       1
# Name: count, dtype: int64
#
# country
# True     7665
# False       3
# Name: count, dtype: int64
#
# budget
# True     5497
# False    2171
# Name: count, dtype: int64
#
# gross
# True     7479
# False     189
# Name: count, dtype: int64
#
# company
# True     7651
# False      17
# Name: count, dtype: int64
#
# runtime
# True     7664
# False       4
# Name: count, dtype: int64

# %% [markdown]
# In the budget columns, there are 2171 null values vs 5497 not null values. Dropping 2171 rows is a lot of data. We will keep the rows with null values for now.

# %%
# Getting the percentage of null values by column
for col in df.columns:
    null_pct=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,null_pct*100))
# Out:
# name - 0.0%
# rating - 1.004173187271779%
# genre - 0.0%
# year - 0.0%
# released - 0.02608242044861763%
# score - 0.03912363067292645%
# votes - 0.03912363067292645%
# director - 0.0%
# writer - 0.03912363067292645%
# star - 0.013041210224308816%
# country - 0.03912363067292645%
# budget - 28.31246739697444%
# gross - 2.464788732394366%
# company - 0.2217005738132499%
# runtime - 0.05216484089723526%

# %% [markdown]
# The budget column has a total of 28% null values. That is a lot of data if dropped.

# %%
# We have to drop all rows with NA because python cannot process null data
df=df.dropna()
for col in df.columns:
    print(df[col].notnull().value_counts(), "\n")
# Out:
# name
# True    5421
# Name: count, dtype: int64
#
# rating
# True    5421
# Name: count, dtype: int64
#
# genre
# True    5421
# Name: count, dtype: int64
#
# year
# True    5421
# Name: count, dtype: int64
#
# released
# True    5421
# Name: count, dtype: int64
#
# score
# True    5421
# Name: count, dtype: int64
#
# votes
# True    5421
# Name: count, dtype: int64
#
# director
# True    5421
# Name: count, dtype: int64
#
# writer
# True    5421
# Name: count, dtype: int64
#
# star
# True    5421
# Name: count, dtype: int64
#
# country
# True    5421
# Name: count, dtype: int64
#
# budget
# True    5421
# Name: count, dtype: int64
#
# gross
# True    5421
# Name: count, dtype: int64
#
# company
# True    5421
# Name: count, dtype: int64
#
# runtime
# True    5421
# Name: count, dtype: int64

# %%
# Checking percentage of null data after dropping all nulls
for col in df.columns:
    null_pct=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,null_pct*100))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %% [markdown]
# We now have a clean data frame without nulls.

# %%
# Let's check data types of each columms
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Votes, budget, gross, and runtime is float type. Let's change the data type of those columns into integer.

# %%
# Converting float types into integers
df['votes']=df['votes'].astype('int64')
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')
df['runtime']=df['runtime'].astype('int64')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime       int64
# dtype: object

# %% [markdown]
# Now all float types are converted into integers.

# %%
# Importing libraries of graphing
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# Exploring total numbers of movies made by directors
directors_movie=df.groupby('director')['name'].count()
directors_movie=directors_movie.sort_values(ascending=False)
print(directors_movie)
# Out:
# director
# Woody Allen         33
# Clint Eastwood      31
# Steven Spielberg    27
# Ron Howard          23
# Ridley Scott        23
#                     ..
# Jerry Paris          1
# Jerry Jameson        1
# Jerrold Freedman     1
# Jeremy Leven         1
# Élie Chouraqui       1
# Name: name, Length: 2063, dtype: int64

# %% [markdown]
# Woody Allen tops the director with the most number of movies made.

# %%
# Most profitable directors ranking
directors_rank=df.groupby('director')['gross'].sum()
directors_rank=directors_rank.sort_values(ascending=False)
print(directors_rank)
# Out:
# director
# Steven Spielberg       9629049370
# Anthony Russo          6844248984
# Peter Jackson          6618045788
# Michael Bay            6451692798
# James Cameron          6248088578
#                           ...
# Stephen Elliott              8315
# Francesca Gregorini          5073
# Stephen Cornwell             2970
# John Fawcett                 2554
# Charles Band                 2270
# Name: gross, Length: 2063, dtype: int64

# %% [markdown]
# Although Woody Allen made the most films, Steven Spielberg still tops the gross ranking.

# %%
# Graphing directors with their total number of movies

directors_movie=df.groupby('director')['name'].count()
plt.figure(figsize=(10, 6))
plt.hist(directors_movie, bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Number of Movies')
plt.ylabel('Number of Directors')
plt.title('Distribution of Movies per Director')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# More than 1400 directors have made only one film, and only two directors have made 30 and above films.

# %%
# Movies released per year 
movies_year=df.groupby('year')['name'].count()
plt.figure(figsize=(10, 6))
plt.plot(movies_year.index, movies_year.values, color='green', marker='o', linestyle='-', label='Movies')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Number of films made per year')
plt.grid(axis='y')
plt.show()

# %%
# Total movies grouped by Genre
movies_genre=df.groupby('genre')['name'].count()
movies_genre
# Out:
# genre
# Action       1415
# Adventure     327
# Animation     277
# Biography     311
# Comedy       1496
# Crime         399
# Drama         863
# Family          4
# Fantasy        41
# Horror        251
# Mystery        17
# Romance         5
# Sci-Fi          6
# Thriller        7
# Western         2
# Name: name, dtype: int64

# %%
# Total movies grouped by Genre
plt.figure(figsize=(10, 6))
plt.bar(movies_genre.index, movies_genre.values, color='cyan', edgecolor='black')
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('Number of Movies')
plt.title('Genres of movies')
plt.grid(axis='y')
plt.show()

# %%
# Movie genres total gross income
sum_genre=df.groupby('genre')['gross'].sum()
sum_genre
# Out:
# genre
# Action       237752868767
# Adventure     43578711908
# Animation     77865909110
# Biography     19093930296
# Comedy        88514817620
# Crime         20017662162
# Drama         52098564769
# Family         2074332587
# Fantasy        1635026609
# Horror        14261055032
# Mystery        2004091467
# Romance         167876905
# Sci-Fi          225660614
# Thriller        297416988
# Western          20025886
# Name: gross, dtype: int64

# %%
# Movie genres total gross income

plt.figure(figsize=(10, 6))
plt.bar(sum_genre.index, sum_genre.values, color='teal', edgecolor='black')
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('Gross Income Total')
plt.title('Genres Income')
plt.grid(axis='y')
plt.show()

# %%
# Movies rating count
rating=df.groupby('rating')['name'].count()
rating
# Out:
# rating
# Approved        1
# G             111
# NC-17          12
# Not Rated      44
# PG            907
# PG-13        1729
# R            2597
# TV-MA           2
# Unrated        17
# X               1
# Name: name, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.bar(rating.index, rating.values, color='teal', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Total Number of Movies')
plt.title('Total Number of Movies by rating')
plt.grid(axis='y')
plt.show()

# %%
# Exploring total numbers of movies per actor
actors_movie=df.groupby('star')['name'].count()
actors_movie=actors_movie.sort_values(ascending=False)
print(actors_movie)
# Out:
# star
# Nicolas Cage           40
# Tom Hanks              38
# Robert De Niro         38
# Bruce Willis           34
# Tom Cruise             33
#                        ..
# Jason Lively            1
# Jason James Richter     1
# Jason Drucker           1
# Jason David Frank       1
# Josh Radnor             1
# Name: name, Length: 1845, dtype: int64

# %% [markdown]
# Nicolas Cage has the most starred movies in the dataset.

# %%
# Most profitable actors ranking
actors_rank=df.groupby('star')['gross'].sum()
actors_rank=actors_rank.sort_values(ascending=False)
print(actors_rank)
# Out:
# star
# Robert Downey Jr.    11855937746
# Tom Hanks             9899944903
# Tom Cruise            9440309875
# Will Smith            7947279234
# Johnny Depp           7410125354
#                         ...
# Louise Lasser               5101
# Brad Johnson                2970
# Emily Perkins               2554
# Robert Glaudini             2270
# Will Friedle                 309
# Name: gross, Length: 1845, dtype: int64

# %% [markdown]
# Robert Downey Jr. aka Ironman is the top earning actor in the dataset.

# %%
# Identifying top 20 grossing movies 

gross_movie=df.groupby('name')['gross'].sum()
gross_movie=gross_movie.sort_values(ascending=False)
print(gross_movie.head(20))
# Out:
# name
# Avatar                                          2847246203
# Avengers: Endgame                               2797501328
# The Lion King                                   2754448457
# Titanic                                         2201647264
# Star Wars: Episode VII - The Force Awakens      2069521700
# Avengers: Infinity War                          2048359754
# Beauty and the Beast                            1689402145
# Jurassic World                                  1670516444
# Aladdin                                         1554744172
# The Avengers                                    1542200454
# Furious 7                                       1515341399
# Frozen II                                       1450026933
# Avengers: Age of Ultron                         1402809540
# Black Panther                                   1347597973
# Harry Potter and the Deathly Hallows: Part 2    1342321665
# Star Wars: Episode VIII - The Last Jedi         1332698830
# ...

# %%
# Visualizing top 20 grossing movies 

gross_movie=df.groupby('name')['gross'].sum()
gross_movie=gross_movie.sort_values(ascending=False)
gross_plot=gross_movie.head(20)

plt.figure(figsize=(10, 6))
plt.barh(gross_plot.index[::-1], gross_plot.values[::-1], color='royalblue', edgecolor='black')
plt.xlabel('Gross by Billion')
plt.ylabel('Movies')
plt.title('Gross of movies')
plt.grid(axis='x')
plt.show()

# %%
# Countries with the most films made

country_movie=df.groupby('country')['name'].count()
country_movie=country_movie.sort_values(ascending=False)
print(country_movie)
# Out:
# country
# United States                     4319
# United Kingdom                     492
# Canada                             111
# France                             105
# Germany                             82
# Australia                           42
# Japan                               28
# China                               26
# Hong Kong                           24
# Ireland                             21
# Italy                               19
# New Zealand                         18
# Spain                               18
# South Korea                         13
# Mexico                              11
# Denmark                             10
# India                                8
# Czech Republic                       7
# Sweden                               5
# Belgium                              4
# Russia                               4
# Switzerland                          4
# South Africa                         4
# Netherlands                          3
# ...

# %%
# Top 20 companies with the most films made

company_movie=df.groupby('company')['name'].count()
company_movie=company_movie.sort_values(ascending=False)
print(company_movie.head(20))
# Out:
# company
# Universal Pictures           330
# Columbia Pictures            302
# Warner Bros.                 298
# Paramount Pictures           279
# Twentieth Century Fox        209
# New Line Cinema              155
# Walt Disney Pictures         107
# Touchstone Pictures          105
# Metro-Goldwyn-Mayer (MGM)     99
# Dreamworks Pictures           75
# TriStar Pictures              75
# Miramax                       66
# Fox 2000 Pictures             58
# Summit Entertainment          57
# Screen Gems                   56
# Lionsgate                     53
# Dimension Films               50
# Fox Searchlight Pictures      48
# Orion Pictures                47
# Castle Rock Entertainment     45
# Name: name, dtype: int64

# %% [markdown]
# Exploring Data Correlation

# %%
df.corr(numeric_only=True, method='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
corr_matrix=df.corr(numeric_only=True, method='pearson')
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Let's explore correlations between values in the dataset. The closer the correlation to 1, the more related the values are.

# %%
#Plotting budget vs gross correlation

plt.scatter(df['budget'], df['gross'])
plt.xlabel('budget')
plt.ylabel('gross')
plt.title('Scatter Plot')
plt.show()

# %%
#Plotting budget vs gross regression
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color': 'blue'})

plt.xlabel('Budget')
plt.ylabel('Gross')
plt.title('Plotting budget vs gross regression')
plt.show()

# %%
#Plotting score vs gross regression
sns.regplot(x='score', y='gross', data=df, scatter_kws={'color': 'purple'}, line_kws={'color': 'blue'})

plt.xlabel('score')
plt.ylabel('Gross')
plt.title('Scatter Plot score vs gross regression')
plt.show()

# %%
#Plotting score vs total votes regression
sns.regplot(x='score', y='votes', data=df, scatter_kws={'color': 'lime'}, line_kws={'color': 'crimson'})

plt.xlabel('score')
plt.ylabel('votes')
plt.title('Plotting score vs total votes regression')
plt.show()

# %%
#Plotting votes vs total gross regression
sns.regplot(x='votes', y='gross', data=df, scatter_kws={'color': 'teal'}, line_kws={'color': 'red'})

plt.xlabel('votes')
plt.ylabel('gross')
plt.title('Plotting votes vs total gross regression')
plt.show()

# %%
#Plotting runtime vs score regression
sns.regplot(x='runtime', y='score', data=df, scatter_kws={'color': 'teal'}, line_kws={'color': 'red'})

plt.xlabel('runtime')
plt.ylabel('score')
plt.title('Scatter Plot  runtime vs score with Regression Line')
plt.show()

# %%
#Plotting year vs budget regression
sns.regplot(x='year', y='budget', data=df, scatter_kws={'color': 'teal'}, line_kws={'color': 'm'})

plt.xlabel('year')
plt.ylabel('budget')
plt.title('Plotting year vs budget regression Line')
plt.show()
